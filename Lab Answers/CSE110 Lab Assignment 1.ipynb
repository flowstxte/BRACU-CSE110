# %% [markdown]
# #Task 1

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# #Task 2

# %%
print(54 + 56)
# Out:
# 110

# %% [markdown]
# #Task 3

# %%
season = "Fall"
year = 2022

print(season)
print(year)
# Out:
# Fall
# 2022

# %% [markdown]
# #Task 4

# %%
name = input("Write your name: ")

print("Your name is",name)
# Out:
# Write your name: John
# Your name is John

# %% [markdown]
# #Task 5

# %%
m = int(input("Write a number: "))
n = int(input("Write the power: "))

print(str(m) + "^" + str(n) + ":", m**n)
# Out:
# Write a number: 2
# Write the power: 3
# 2^3: 8

# %% [markdown]
# #Task 6

# %%
weight = int(input("Total weight: "))

print((weight // 4) * 4)
# Out:
# Total weight: 9
# 8

# %% [markdown]
# #Task 7

# %%
a = float(input("A = "))
b = float(input("B = "))
c = float(input("C = "))
d = float(input("D = "))

print(int(a ** c + b * a - d / 3))
# Out:
# A = 2
# B = 6
# C = 8
# D = 1.3
# 267

# %% [markdown]
# #Task 8

# %%
num = int(input("Number of chocolates: "))

print("Each friend will receive", num // 3 ,"chocolates")
print("The number of remaining chocolates is", num % 3)
# Out:
# Number of chocolates: 50
# Each friend will receive 16 chocolates
# The number of remaining chocolates is 2

# %% [markdown]
# #Task 9

# %%
m = input("Write something: ")
n = input("Write something again: ")

print(n+m)
# Out:
# Write something: 5
# Write something again: 2
# 25

# %% [markdown]
# #Task 10

# %%
value = input("Write anything: ")

print(value[0])
# Out:
# Write anything: Python
# P

# %% [markdown]
# #Task 11

# %%
number = int(input("Check if the number is even or not: "))

mod = number % 2

if mod == 0:
  print("True")
else:
  print("False")
# Out:
# Check if the number is even or not: 7
# False
